# %%
# Dependencies
import requests
import json

# %%
# URL for GET requests to retrieve vehicle data
url = "https://developer.nrel.gov/api/alt-fuel-stations/v1.json?limit=15&api_key=NFwYdHUM4ZpItnrfWegNs0sBSvdUplNebaTPO3RZ"
#fuel type electric

# %%
# Print the response object to the console
print(requests.get(url))
# Out:
# <Response [200]>

# %%
# Retrieving data and converting it into JSON
print(requests.get(url).json())
# Out:
# {'station_locator_url': 'https://afdc.energy.gov/stations/', 'total_results': 77153, 'station_counts': {'total': 187087, 'fuels': {'BD': {'total': 1695}, 'E85': {'total': 4480}, 'ELEC': {'total': 175767, 'stations': {'total': 65833}}, 'HY': {'total': 127}, 'LNG': {'total': 133}, 'CNG': {'total': 1440}, 'LPG': {'total': 2859}, 'RD': {'total': 586}}}, 'fuel_stations': [{'access_code': 'private', 'access_days_time': None, 'access_detail_code': None, 'cards_accepted': None, 'date_last_confirmed': '2023-04-06', 'expected_date': None, 'fuel_type_code': 'CNG', 'groups_with_access_code': 'Private', 'id': 17, 'open_date': '2010-12-01', 'owner_type_code': 'T', 'status_code': 'E', 'restricted_access': None, 'maximum_vehicle_class': 'MD', 'station_name': 'Spire - Montgomery Operations Center', 'station_phone': None, 'updated_at': '2023-05-30T18:46:28Z', 'facility_type': 'STANDALONE_STATION', 'geocode_status': '200-9', 'latitude': 32.367916, 'longitude': -86.267021, 'city': 'Montgomery', 'intersection_directions': None, 'plus4': None, 'state': 'AL', 'street_address': '2951 Chestnut St', 'zip': '36107', 'country': 'US', 'bd_blends': None, 'cng_dispenser_num': None, 'cng_fill_type_code': 'B', 'cng_psi': '3600', 'cng_renewable_source': None, 'cng_total_compression': None, 'cng_total_storage': None, 'cng_vehicle_class': 'MD', 'cng_has_rng': False, 'e85_blender_pump': None, 'e85_other_ethanol_blends': None, 'ev_connector_types': None, 'ev_dc_fast_num': None, 'ev_level1_evse_num': None, 'ev_level2_evse_num': None, 'ev_network': None, 'ev_network_web': None, 'ev_other_evse': None, 'ev_pricing': None, 'ev_renewable_source': None, 'hy_is_retail': None, 'hy_pressures': None, 'hy_standards': None, 'hy_status_link': None, 'lng_renewable_source': None, 'lng_vehicle_class': None, 'lng_has_rng': None, 'lpg_primary': None, 'lpg_nozzle_types': None, 'ng_fill_type_code': 'B', 'ng_psi': '3600', 'ng_vehicle_class': 'MD', 'rd_blends': None, 'rd_blends_fr': None, 'rd_blended_with_biodiesel': None, 'rd_max_biodiesel_level': None, 'nps_unit_name': None, 'access_days_time_fr': None, 'intersection_directions_fr': None, 'bd_blends_fr': None, 'groups_with_access_code_fr': 'Privé', 'ev_pricing_fr': None}, {'access_code': 'private', 'access_days_time': None, 'access_detail_code': 'GOVERNMENT', 'cards_accepted': None, 'date_last_confirmed': '2023-01-10', 'expected_date': None, 'fuel_type_code': 'CNG', 'groups_with_access_code': 'Private - Government only', 'id': 45, 'open_date': '1996-12-15', 'owner_type_code': 'LG', 'status_code': 'E', 'restricted_access': None, 'maximum_vehicle_class': 'LD', 'station_name': 'Metropolitan Atlanta Rapid Transit Authority', 'station_phone': None, 'updated_at': '2023-08-01T22:53:06Z', 'facility_type': 'FLEET_GARAGE', 'geocode_status': '200-8', 'latitude': 33.821911, 'longitude': -84.367461, 'city': 'Atlanta', 'intersection_directions': None, 'plus4': None, 'state': 'GA', 'street_address': '2424 Piedmont Rd NE', 'zip': '30324', 'country': 'US', 'bd_blends': None, 'cng_dispenser_num': None, 'cng_fill_type_code': 'Q', 'cng_psi': '3000', 'cng_renewable_source': None, 'cng_total_compression': 30, 'cng_total_storage': None, 'cng_vehicle_class': 'LD', 'cng_has_rng': None, 'e85_blender_pump': None, 'e85_other_ethanol_blends': None, 'ev_connector_types': None, 'ev_dc_fast_num': None, 'ev_level1_evse_num': None, 'ev_level2_evse_num': None, 'ev_network': None, 'ev_network_web': None, 'ev_other_evse': None, 'ev_pricing': None, 'ev_renewable_source': None, 'hy_is_retail': None, 'hy_pressures': None, 'hy_standards': None, 'hy_status_link': None, 'lng_renewable_source': None, 'lng_vehicle_class': None, 'lng_has_rng': None, 'lpg_primary': None, 'lpg_nozzle_types': None, 'ng_fill_type_code': 'Q', 'ng_psi': '3000', 'ng_vehicle_class': 'LD', 'rd_blends': None, 'rd_blends_fr': None, 'rd_blended_with_biodiesel': None, 'rd_max_biodiesel_level': None, 'nps_unit_name': None, 'access_days_time_fr': None, 'intersection_directions_fr': None, 'bd_blends_fr': None, ' ...

# %%
# Pretty Print the output of the JSON
response = requests.get(url).json()
print(json.dumps(response, indent=4, sort_keys=True))
# Out:
# {
#     "fuel_stations": [
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Montgomery",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "B",
#             "cng_has_rng": false,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2023-04-06",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "STANDALONE_STATION",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private",
#             "groups_with_access_code_fr": "Priv\u00e9",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 17,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 32.367916,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -86.267021,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "B",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "2010-12-01",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": null,
#             "state": "AL",
#             "station_name": "Spire - Montgomery Operations Center",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "2951 Chestnut St",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "36107"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": "GOVERNMENT",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Atlanta",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3000",
#             "cng_renewable_source": null,
#             "cng_total_compression": 30,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "LD",
#             "country": "US",
#             "date_last_confirmed": "2023-01-10",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "FLEET_GARAGE",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Private - Government only",
#             "groups_with_access_code_fr": "Priv\u00e9 - R\u00e9serv\u00e9 au gouvernement",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 45,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 33.821911,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -84.367461,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "LD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000",
#             "ng_vehicle_class": "LD",
#             "nps_unit_name": null,
#             "open_date": "1996-12-15",
#             "owner_type_code": "LG",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": null,
#             "state": "GA",
#             "station_name": "Metropolitan Atlanta Rapid Transit Authority",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "2424 Piedmont Rd NE",
#             "updated_at": "2023-08-01T22:53:06Z",
#             "zip": "30324"
#         },
#         {
#             "access_code": "private",
#             "access_days_time": null,
#             "access_days_time_fr": null,
#             "access_detail_code": null,
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Atlanta",
#             "cng_dispenser_num": null,
#             "cng_fill_type_code": "B",
#             "cng_has_rng": null,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": null,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "STANDALONE_STATION",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Private",
#             "groups_with_access_code_fr": "Priv\u00e9",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 64,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 33.760256,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -84.543822,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "HD",
#             "ng_fill_type_code": "B",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "HD",
#             "nps_unit_name": null,
#             "open_date": "1997-01-01",
#             "owner_type_code": "P",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": null,
#             "state": "GA",
#             "station_name": "United Parcel Service",
#             "station_phone": null,
#             "status_code": "E",
#             "street_address": "270 Marvin Miller Dr",
#             "updated_at": "2023-08-03T03:41:49Z",
#             "zip": "30336"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "FuelMan M V Wright_Exp",
#             "city": "Fort Smith",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": false,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 250,
#             "cng_total_storage": 57855,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2023-08-10",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 73,
#             "intersection_directions": null,
#             "intersection_directions_fr": null,
#             "latitude": 35.362213,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -94.375338,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1997-01-01",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "AR",
#             "station_name": "Arkansas Oklahoma Gas Corp",
#             "station_phone": "479-783-3181",
#             "status_code": "E",
#             "street_address": "2100 S Waldron Rd",
#             "updated_at": "2023-08-10T16:58:49Z",
#             "zip": "72903"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 866-809-4869 for Clean Energy card",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "A CleanEnergy Comdata D FuelMan M V Voyager Wright_Exp",
#             "city": "East Boston",
#             "cng_dispenser_num": 4,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": true,
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": "NONE",
#             "cng_total_compression": 850,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2023-09-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "AIRPORT",
#             "fuel_type_code": "CNG",
#             "geocode_status": "GPS",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 81,
#             "intersection_directions": "From Route 1, take the first exit after Callahan Tunnel. Located near the Massachusetts State Police Troop F building on Service Rd.",
#             "intersection_directions_fr": null,
#             "latitude": 42.37470554648246,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -71.02654860574343,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1996-11-15",
#             "owner_type_code": "SG",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "MA",
#             "station_name": "Clean Energy - Logan International Airport",
#             "station_phone": "866-809-4869",
#             "status_code": "E",
#             "street_address": "1000 Cottage St Ext",
#             "updated_at": "2023-09-14T14:01:49Z",
#             "zip": "02128"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 866-809-4869 for Clean Energy card",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "CleanEnergy D FleetOne FuelMan M V Voyager Wright_Exp",
#             "city": "Everett",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": false,
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 425,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2022-12-13",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "STANDALONE_STATION",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 84,
#             "intersection_directions": "Rt 16, exit to Rt 99, to Dexter St to Rover. Or Rt 99 to Robin St, to Rover St",
#             "intersection_directions_fr": null,
#             "latitude": 42.393167,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -71.064352,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "HD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "HD",
#             "nps_unit_name": null,
#             "open_date": "1996-11-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "MA",
#             "station_name": "Clean Energy - Everett - National Grid",
#             "station_phone": "866-809-4869",
#             "status_code": "E",
#             "street_address": "16 Rover St",
#             "updated_at": "2023-08-25T15:12:32Z",
#             "zip": "02149"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 866-809-4869 for Clean Energy card",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "CleanEnergy D FuelMan M V Voyager Wright_Exp",
#             "city": "Brooklyn",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": true,
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": "NONE",
#             "cng_total_compression": 1200,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "HD",
#             "country": "US",
#             "date_last_confirmed": "2023-09-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 108,
#             "intersection_directions": "I-278/Brooklyn Queens Expy, exit onto Vandervoort Ave S, left onto Maspeth Ave, and the station is on the left",
#             "intersection_directions_fr": null,
#             "latitude": 40.718037,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.932309,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "HD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "HD",
#             "nps_unit_name": null,
#             "open_date": "2016-07-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Clean Energy - Greenpoint - National Grid",
#             "station_phone": "866-809-4869",
#             "status_code": "E",
#             "street_address": "287 Maspeth Ave",
#             "updated_at": "2023-09-14T14:01:49Z",
#             "zip": "11211"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 866-809-4869 for Clean Energy card; Also accepts OGS",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "CleanEnergy D FleetOne FuelMan M Proprietor V Voyager Wright_Exp",
#             "city": "Brooklyn",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "B",
#             "cng_has_rng": null,
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": "NONE",
#             "cng_total_compression": 525,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-12-13",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 112,
#             "intersection_directions": "From Shore Pkwy, take Rockaway Pkwy N, left onto Ditmas Ave, and station is on the left",
#             "intersection_directions_fr": null,
#             "latitude": 40.64554,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.918344,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "B",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1988-01-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Canarsie - National Grid",
#             "station_phone": "866-809-4869",
#             "status_code": "E",
#             "street_address": "8424 Ditmas Ave",
#             "updated_at": "2023-08-15T20:45:48Z",
#             "zip": "11236"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 718-204-4100 to arrange for card key",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "New York",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 300,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 124,
#             "intersection_directions": "In Manhattan, W 29th Street and 12th Avenue.",
#             "intersection_directions_fr": null,
#             "latitude": 40.752903,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -74.005831,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "2014-05-01",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Con Edison - W 29th St Service Center",
#             "station_phone": "212-643-3054",
#             "status_code": "E",
#             "street_address": "281 11th Ave",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "10001"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 718-204-4048 to arrange for card key",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "New York",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 300,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 125,
#             "intersection_directions": "In Manhattan, at Avenue C and E 16th. Broadway: Turn east onto 14th Street, then left onto 1st Avenue at 16th Street.",
#             "intersection_directions_fr": null,
#             "latitude": 40.729175,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.97331,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1998-01-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Con Edison - E 16th St Service Center",
#             "station_phone": "212-460-6708",
#             "status_code": "E",
#             "street_address": "700 E 16th St",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "10009"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "8am-6pm M-F, call 718-204-4048 to arrange for card key",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Bronx",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3000",
#             "cng_renewable_source": null,
#             "cng_total_compression": 300,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "GPS",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 129,
#             "intersection_directions": "Hutchinson River Parkway, exit onto E Tremont Avenue W, right onto Bronxdale Avenue, station on the left. From I-95, take Castle Hill Avenue exit north to E Tremont and Bronx.",
#             "intersection_directions_fr": null,
#             "latitude": 40.8441883,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.8615724,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1998-01-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Con Edison - Van Nest Service Center",
#             "station_phone": "718-904-4504",
#             "status_code": "E",
#             "street_address": "1615 Bronxdale Ave",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "10462"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "8am-8pm M-F; call 718-204-4048 to arrange for card key",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Rye",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 60,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 130,
#             "intersection_directions": "I-95/New England Thruway, exit 19 onto Playland Pkwy Service Rd going south, left onto Theodore Fremd Ave, station on left.",
#             "intersection_directions_fr": null,
#             "latitude": 40.979001,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.693048,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1996-12-03",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Con Edison - Rye Service Center",
#             "station_phone": "914-933-2910",
#             "status_code": "E",
#             "street_address": "178 Theodore Fremd Ave",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "10580"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "7am-11pm M-F, 7am-3pm Sat-Sun; call 718-204-4048 to arrange for card key",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": null,
#             "city": "Queens",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": null,
#             "cng_psi": "3000",
#             "cng_renewable_source": null,
#             "cng_total_compression": 300,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-06-14",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 132,
#             "intersection_directions": "From I-678/Whitestone Expressway, exit at Linden Place, I-678 service road W, right onto 31st Avenue, station at intersection with College Point Boulevard.",
#             "intersection_directions_fr": null,
#             "latitude": 40.769623,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -73.843069,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1998-01-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "NY",
#             "station_name": "Con Edison - College Point Service Center",
#             "station_phone": "718-321-4608",
#             "status_code": "E",
#             "street_address": "124-15 31st Ave",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "11354"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily",
#             "access_days_time_fr": null,
#             "access_detail_code": "CREDIT_CARD_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "D M V Wright_Exp",
#             "city": "Indianapolis",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": false,
#             "cng_psi": "3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 720,
#             "cng_total_storage": 34500,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2022-10-11",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "STANDALONE_STATION",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-9",
#             "groups_with_access_code": "Public - Credit card at all times",
#             "groups_with_access_code_fr": "Public - Carte de cr\u00e9dit en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 147,
#             "intersection_directions": "I-65, exit onto Raymond Street W.",
#             "intersection_directions_fr": null,
#             "latitude": 39.736169,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -86.161743,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1991-03-15",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "IN",
#             "station_name": "CNG Source Fueling - Greene's Auto & Truck Service",
#             "station_phone": "317-353-8241",
#             "status_code": "E",
#             "street_address": "111 W Raymond St",
#             "updated_at": "2023-09-20T17:09:47Z",
#             "zip": "46225"
#         },
#         {
#             "access_code": "public",
#             "access_days_time": "24 hours daily; call 866-809-4869 for Clean Energy card",
#             "access_days_time_fr": null,
#             "access_detail_code": "KEY_ALWAYS",
#             "bd_blends": null,
#             "bd_blends_fr": null,
#             "cards_accepted": "CleanEnergy",
#             "city": "Cheyenne",
#             "cng_dispenser_num": 1,
#             "cng_fill_type_code": "Q",
#             "cng_has_rng": false,
#             "cng_psi": "3000 3600",
#             "cng_renewable_source": null,
#             "cng_total_compression": 270,
#             "cng_total_storage": null,
#             "cng_vehicle_class": "MD",
#             "country": "US",
#             "date_last_confirmed": "2023-03-08",
#             "e85_blender_pump": null,
#             "e85_other_ethanol_blends": null,
#             "ev_connector_types": null,
#             "ev_dc_fast_num": null,
#             "ev_level1_evse_num": null,
#             "ev_level2_evse_num": null,
#             "ev_network": null,
#             "ev_network_web": null,
#             "ev_other_evse": null,
#             "ev_pricing": null,
#             "ev_pricing_fr": null,
#             "ev_renewable_source": null,
#             "expected_date": null,
#             "facility_type": "UTILITY",
#             "fuel_type_code": "CNG",
#             "geocode_status": "200-8",
#             "groups_with_access_code": "Public - Card key at all times",
#             "groups_with_access_code_fr": "Public - Carte-cl\u00e9 en tout temps",
#             "hy_is_retail": null,
#             "hy_pressures": null,
#             "hy_standards": null,
#             "hy_status_link": null,
#             "id": 215,
#             "intersection_directions": "From I-25 take exit 10, Missile Dr, go approximately 0.5 miles to W 24th St, then turn left onto W 24th.  The fueling station is located on the right",
#             "intersection_directions_fr": null,
#             "latitude": 41.135848,
#             "lng_has_rng": null,
#             "lng_renewable_source": null,
#             "lng_vehicle_class": null,
#             "longitude": -104.830233,
#             "lpg_nozzle_types": null,
#             "lpg_primary": null,
#             "maximum_vehicle_class": "MD",
#             "ng_fill_type_code": "Q",
#             "ng_psi": "3000 3600",
#             "ng_vehicle_class": "MD",
#             "nps_unit_name": null,
#             "open_date": "1996-12-03",
#             "owner_type_code": "T",
#             "plus4": null,
#             "rd_blended_with_biodiesel": null,
#             "rd_blends": null,
#             "rd_blends_fr": null,
#             "rd_max_biodiesel_level": null,
#             "restricted_access": false,
#             "state": "WY",
#             "station_name": "Black Hills Energy",
#             "station_phone": "307-638-3361",
#             "status_code": "E",
#             "street_address": "1301 W 24th St",
#             "updated_at": "2023-05-30T18:46:28Z",
#             "zip": "82001"
#         }
#     ],
#     "station_counts": {
#         "fuels": {
#             "BD": {
#                 "total": 1695
#             },
#             "CNG": {
#                 "total": 1440
#             },
#             "E85": {
#                 "total": 4480
#             },
#             "ELEC": {
#                 "stations": {
#                     "total": 65833
#                 },
#                 "total": 175767
#             },
#             "HY": {
#                 "total": 127
#             },
#             "LNG": {
#                 "total": 133
#             },
#             "LPG": {
#                 "total": 2859
#             },
#             "RD": {
#                 "total": 586
#             }
#         },
#         "total": 187087
#     },
#     "station_locator_url": "https://afdc.energy.gov/stations/",
#     "total_results": 77153
# }
